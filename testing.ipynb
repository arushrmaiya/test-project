# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
link = 'https://letterboxd.com/gojizillakong/list/favourite-movies/'

# %%
req = requests.get(link)

# %%
soup = bs(req.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-mobile no-js" id="html" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=1024" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="A list of 16 films compiled on Letterboxd, including Shin Godzilla (2016), Godzilla (1954), Wolf Children (2012), Neon Genesis Evangelion: The End of Evangelion (1997) and Spider-Man: Into the Spider-Verse (2018). About this list: My favourite movies in no particular order" name="description"/>
# <meta content="letterboxd:list" property="og:type"/>
# <meta content="https://letterboxd.com/gojizillakong/list/favourite-movies/" property="og:url"/>
# <meta content="Favourite movies" property="og:title"/>
# <meta content="My favourite movies in no particular order" property="og:description"/>
# ...

# %%
for w in soup.find_all("li", {"class":"poster-container"}):
    x = w.find("div")
    print(x["data-film-slug"])
# Out:
# shin-godzilla-orthochromatic
# godzilla
# wolf-children
# neon-genesis-evangelion-the-end-of-evangelion
# spider-man-into-the-spider-verse
# walle
# the-iron-giant
# godzilla-king-of-the-monsters-2019
# parasite-2019
# evangelion-3010-thrice-upon-a-time
# spider-man-across-the-spider-verse
# godzilla-minus-one
# the-boy-and-the-heron
# dune-part-two
# castle-in-the-sky
# perfect-blue

# %%
link_test = 'https://letterboxd.com/film/godzilla-minus-one/'
req_test = requests.get(link_test)
soup_test = bs(req_test.text, 'html.parser')

# %%
soup_test
# Out:
# <!DOCTYPE html>
#
# <html class="no-mobile no-js" id="html" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=1024" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="In postwar Japan, a new terror rises. Will the devastated people be able to survive... let alone fight back?" name="description"/>
# <meta content="video.movie" property="og:type"/>
# <meta content="https://letterboxd.com/film/godzilla-minus-one/" property="og:url"/>
# <meta content="Godzilla Minus One (2023)" property="og:title"/>
# <meta content="In postwar Japan, a new terror rises. Will the devastated people be able to survive... let alone fight back?" property="og:description"/>
# <meta content="https://a.ltrbxd.com/resized/sm/upload/wt/xq/8w/wb/godzilla-1200-1200-675-675-crop-000000.jpg?v=5defa22bec" property="og:image"/><meta content="1200" property="og:image:width"/><meta content="675" property="og:image:height"/>
# ...

# %%
for s in soup_test.find_all("script"):
    print(s)
# Out:
# <script>
#
# 		((r, n) => {
# 			r.dataset.useragent = n.userAgent
# 			r.dataset.platform = n.platform
# 		})(document.documentElement, navigator)
#
# 		var isMobile = false,
# 			isMobileOptimised = true,
# 			renderMobile = false,
# 			useStaticFonts = false,
# 			disableFrameProtection = false,
# 			baseURL = "",
# 			successMessages = [],
# 			errorMessages = [],
# 			stickyMessages = [],
# 			globals = {
# 			autoAddFilm: false
# 				, spinners: {
# 					ajax_242d35: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.ab23ec0b.gif',
# 					spinner_12_2C3641: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.ab23ec0b.gif',
# 					spinner_14_20272f: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.ab23ec0b.gif',
# 					spinner_16_161B21: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.ab23ec0b.gif'
# 				}
# 			},
# 			supermodelCSRF = "",
# 			gRecaptchaKey = '6Le3mMIUAAAAAEXbwZ7M1R5jEv0V5xbvj7bgXq2g',
# 			geolocation = {
# 				country: ""
# 			},
# 			person = {
# ...
